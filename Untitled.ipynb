# %%
import pandas as pd
import re
import functions
import nltk
import sklearn
from sklearn.linear_model import LogisticRegression
from nltk.stem import PorterStemmer

# %%
data = pd.read_csv("train_posts.csv", header=None)

# %%
porter = PorterStemmer()

# %%
imax = 30000
imin = 25000

# %%
preprocessed = []
repeat = 0
for i, tweet in enumerate(data[0].values[:imax]):
    tmp = tweet.lower()
    tmp = re.sub("[0-9]{1,2}/[0-9]{1,2}/([0-9]{4}|[0-9]{2})|([0-9]{4}|[0-9]{2})/[0-9]{1,2}/[0-9]{1,2}|[0-9]{2}/[0-9]{2}", "DATE", tmp)
    tmp = re.sub("[0-9]{2}(:[0-9]{2}){1,2}( ?(am|pm|p\.m\.|a\.m\.))?", "TIME", tmp)
    tmp = re.sub("[0-9]+", " nb ", tmp)
    tmp = tmp.encode(encoding='ascii', errors='ignore').decode()
    # get rid of the non ascii characters
    tmp = re.sub("\.{2,}", "...", tmp)
    for c in ['!', '-', ',']:
        tmp = re.sub("{}+".format(c), c, tmp)
    tmp = re.sub("\?+", "?", tmp)
    tmp = re.sub("`+", "'", tmp)
    tmp = re.sub("'{2,}", "'", tmp)
    tmp = tmp.translate(str.maketrans(dict.fromkeys('#*+/<=>@[\\]^_`{|}~'))) #removing all the other special characters
    tokens = [t if t not in ["''", "``"] else '"' for t in nltk.tokenize.word_tokenize(tmp) ]
    # tokenizing using nltk.word_tokenize. althought it transforms '"' into '``' or "''" and this is a behaviour do not want
    # so we make sure that the '"' are changed to their original form
    for i, token in enumerate(tokens):
        if re.search(r"([a-z])\1{2,}", token):
            repeat += 1
            # cleaning the words containing a letter repeated 3 times or more, using the list of the Ensglish words
            tokens[i] = functions.clean(token)
        tokens[i] = porter.stem(tokens[i])
    preprocessed.append(tokens)
print("{} words with repetitions cleaned".format(repeat))
# Out:
# 6566 words with repetitions cleaned

# %%
vectorizer = sklearn.feature_extraction.text.TfidfVectorizer(min_df=0.0001, stop_words='english', ngram_range=(1,2))

# %%
X = vectorizer.fit_transform([' '.join(post) for post in preprocessed[:]])
Y_train = data[1].values[:imin]
#X_test = vectorizer.transform([' '.join(post) for post in preprocessed[imin:]])
X_train = X[:imin]
X_test = X[imin:]
Y_test =  data[1].values[imin:imax]

# %%
len(vectorizer.get_feature_names())
# Out:
# 149526

# %%
clf = LogisticRegression(C=5,class_weight='balanced', solver='newton-cg',multi_class='multinomial', n_jobs=-1,\
                         random_state=40, verbose=1, penalty='l2')
clf.fit(X_train, Y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 out of   1 | elapsed:    8.9s finished
# LogisticRegression(C=5, class_weight='balanced', dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='multinomial', n_jobs=-1, penalty='l2',
#                    random_state=40, solver='newton-cg', tol=0.0001, verbose=1,
#                    warm_start=False)

# %%
clf.score(X_train,Y_train)
# Out:
# 0.98916

# %%
clf.score(X_test, Y_test)
# Out:
# 0.632

# %%
print(vectorizer.get_feature_names())
# Out:
# ['aa', 'aa meet', 'aac', 'aag', 'aah', 'aahh', 'aan', 'aar', 'aardvark', 'aaron', 'aaron carter', 'aaron sorkin', 'aaron spell', 'aaww', 'aay', 'aaya', 'ab', 'aba', 'aback', 'abacu', 'abad', 'abandon', 'abandon issu', 'abandon thi', 'abb', 'abba', 'abbey', 'abbi', 'abbi got', 'abbi wa', 'abbott', 'abbrevi', 'abby', 'abc', 'abc affili', 'abc nb', 'abc news', 'abc onli', 'abck', 'abd', 'abdomen', 'abdomin', 'abduct', 'abdul', 'abe', 'abercrombi', 'abercrombi chick', 'abercrombi fitch', 'aberdeen', 'aberr', 'abhi', 'abhor', 'abhorr', 'abi', 'abi friend', 'abi gavin', 'abi nb', 'abid', 'abil', 'abil accept', 'abil ask', 'abil commun', 'abil connect', 'abil creat', 'abil develop', 'abil good', 'abil make', 'abil peopl', 'abil play', 'abil read', 'abil realli', 'abil speak', 'abil tell', 'abil use', 'abil win', 'abil work', 'abit', 'abject', 'abl', 'abl access', 'abl accomplish', 'abl achiev', 'abl add', 'abl afford', 'abl ani', 'abl anoth', 'abl answer', 'abl anyth', 'abl appreci', 'abl ask', 'abl attend', 'abl away', 'abl becaus', 'abl better', 'abl break', 'abl breath', 'abl bring', 'abl buy', 'abl ca', 'abl care', 'abl carri', 'abl catch', 'abl chang', 'abl check', 'abl choos', 'abl come', 'abl comfort', 'abl commun', 'abl complet', 'abl comprehend', 'abl connect', 'abl continu', 'abl control', 'abl convinc', 'abl cut', 'abl decent', 'abl drink', 'abl drive', 'abl eat', 'abl enjoy', 'abl escap', 'abl everyth', 'abl experi', 'abl explain', 'abl express', 'abl fall', 'abl feel', 'abl figur', 'abl finish', 'abl fit', 'abl fix', 'abl friend', 'abl fulli', 'abl fun', 'abl function', 'abl good', 'abl graduat', 'abl guy', 'abl handl', 'abl hang', 'abl hear', 'abl help', 'abl hi', 'abl hit', 'abl hold', 'abl home', 'abl join', 'abl just', 'abl kick', 'abl kill', 'abl late', 'abl leav', 'abl let', 'abl like', 'abl link', 'abl listen', 'abl live', 'abl look', 'abl lot', 'abl love', 'abl maintain', 'abl make', 'abl meet', 'abl nb', 'abl new', 'abl offer', 'abl onli', 'abl onlin', 'abl open', 'abl pay', 'abl pick', 'abl place', 'abl plan', 'abl play', 'abl post', 'abl provid', 'abl pull', 'abl reach', 'abl read', 'abl realli', 'abl relat', 'abl relax', 'abl rememb', 'abl repli', 'abl return', 'abl run', 'abl save', 'abl say', 'abl school', 'abl sell', 'abl send', 'abl set', 'abl share', 'abl shop', 'abl sing', 'abl sleep', 'abl solv', 'abl someth', 'abl speak', 'abl spend', 'abl stand', 'abl start', 'abl stay', 'abl stop', 'abl studi', 'abl surviv', 'abl talk', 'abl tell', 'abl thi', 'abl thing', 'abl think', 'abl time', 'abl togeth', 'abl touch', 'abl tri', 'abl trust', 'abl turn', 'abl type', 'abl understand', 'abl updat', 'abl urllink', 'abl use', 'abl wa', 'abl walk', 'abl want', 'abl watch', 'abl week', 'abl word', 'abl work', 'abl world', 'abl write', 'ablaz', 'abnorm', 'aboard', 'abod', 'abolish', 'abolit', 'abomin', 'abort', 'abort becaus', 'abort clinic', 'abort gay', 'abort nb', 'abort wrong', 'abotu', 'abou', 'abound', 'abov', 'abov anim', 'abov averag', 'abov blog', 'abov els', 'abov eye', 'abov ground', 'abov ha', 'abov head', 'abov hi', 'abov just', 'abov law', 'abov mention', 'abov nb', 'abov need', 'abov realli', 'abov referenc', 'abov rest', 'abov sad', 'abov shoulder', 'abov statement', 'abov thi', 'abov thing', 'abov think', 'abov wa', 'abov water', 'abra', 'abraham', 'abraham lincoln', 'abras', 'abrazo', 'abreast', 'abridg', 'abridg version', 'abroad', 'abroad credit', 'abrupt', 'abrupt end', 'abruptli', 'abs', 'abscess', 'absenc', 'absenc ani', 'absenc make', 'absent', 'absente', 'absente ballot', 'absinth', 'absolulti', 'absolut', 'absolut ador', 'absolut amaz', 'absolut awesom', 'absolut beauti', 'absolut best', 'absolut brilliant', 'absolut clue', 'absolut crap', 'absolut crazi', 'absolut delight', 'absolut disgust', 'absolut everyth', 'absolut fabul', 'absolut fantast', 'absolut favorit', 'absolut gorgeou', 'absolut hate', 'absolut hilari', 'absolut horribl', 'absolut idea', 'absolut kill', 'absolut love', 'absolut  ...
